# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import datetime
from datetime import datetime as dt

# %%
f1 = pd.read_excel("E:/KESHMINA/M-Tech/Semester-2/ES 670/drive-download-20220127T074114Z-001/PM Jan 2020.xlsx", sheet_name="MX_B_108")
f2 = pd.read_excel("E:/KESHMINA\M-Tech/Semester-2/ES 670/drive-download-20220127T074114Z-001/PM Feb 2020.xlsx", sheet_name="MX_B_108")
f3 = pd.read_excel("E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\PM Mar 2020.xlsx", sheet_name="MX_B_108")
f4 = pd.read_excel("E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\PM Apr 2020.xlsx", sheet_name="MX_B_108")
f5 = pd.read_excel("E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\PM May 2020.xlsx", sheet_name="MX_B_108")
f6 = pd.read_excel("E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\PM Jun 2020.xlsx", sheet_name="MX_B_108")
f7 = pd.read_excel("E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\PM Jul 2020.xlsx", sheet_name="MX_B_108")
f8 = pd.read_excel("E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\PM Aug 2020.xlsx", sheet_name="MX_B_108")

# %%
f1['Timestamp'].astype('datetime64[ns]')
# Out:
# 0       2020-01-27 13:30:45
# 1       2020-01-27 13:31:15
# 2       2020-01-27 13:31:45
# 3       2020-01-27 13:32:15
# 4       2020-01-27 13:32:45
#                 ...
# 12788   2020-01-31 23:57:40
# 12789   2020-01-31 23:58:10
# 12790   2020-01-31 23:58:40
# 12791   2020-01-31 23:59:10
# 12792   2020-01-31 23:59:40
# Name: Timestamp, Length: 12793, dtype: datetime64[ns]

# %%
f1['new_date'] = f1['Timestamp'].dt.date
f1['new_time'] = f1['Timestamp'].dt.time
f2['new_date'] = f2['Timestamp'].dt.date
f2['new_time'] = f2['Timestamp'].dt.time
f3['new_date'] = f3['Timestamp'].dt.date
f3['new_time'] = f3['Timestamp'].dt.time
f4['new_date'] = f4['Timestamp'].dt.date
f4['new_time'] = f4['Timestamp'].dt.time
f5['new_date'] = f5['Timestamp'].dt.date
f5['new_time'] = f5['Timestamp'].dt.time
f6['new_date'] = f6['Timestamp'].dt.date
f6['new_time'] = f6['Timestamp'].dt.time
f7['new_date'] = f7['Timestamp'].dt.date
f7['new_time'] = f7['Timestamp'].dt.time
f8['new_date'] = f8['Timestamp'].dt.date
f8['new_time'] = f8['Timestamp'].dt.time

# %%
list = [f1, f2, f3, f4, f5, f6, f7, f8]

# %%
for item in list:
    a = item['PM2.5_Atm(ug/m3)'].describe()
    print(a)
# Out:
# count    12793.000000
# mean        28.056281
# std         13.476073
# min          0.000000
# 25%         17.000000
# 50%         30.000000
# 75%         37.000000
# max        167.000000
# Name: PM2.5_Atm(ug/m3), dtype: float64
# count    70674.000000
# mean        43.999406
# std         14.220777
# min          0.000000
# 25%         36.000000
# 50%         44.000000
# 75%         50.000000
# max        402.000000
# Name: PM2.5_Atm(ug/m3), dtype: float64
# count    60203.000000
# mean        21.122618
# std         18.326305
# min          0.000000
# 25%          8.000000
# 50%         17.000000
# 75%         33.000000
# max        472.000000
# Name: PM2.5_Atm(ug/m3), dtype: float64
# count    74669.000000
# mean        27.476449
# std         11.770591
# min          0.000000
# 25%         20.000000
# 50%         29.000000
# 75%         35.000000
# max        162.000000
# Name: PM2.5_Atm(ug/m3), dtype: float64
# count    70043.000000
# mean        17.769856
# ...

# %%
df = pd.concat(list, axis = 0)

# %%
df
# Out:
#                 Timestamp  Temperature(C)  Humidity(%)  Pressure(Pa)  \
# 0     2020-01-27 13:30:45              28           32         86154
# 1     2020-01-27 13:31:15              28           32         86150
# 2     2020-01-27 13:31:45              27           33         86149
# 3     2020-01-27 13:32:15              27           33         86150
# 4     2020-01-27 13:32:45              27           33         86149
# ...                   ...             ...          ...           ...
# 86585 2020-08-31 23:57:36              21           80         86082
# 86586 2020-08-31 23:58:06              21           80         86081
# 86587 2020-08-31 23:58:36              21           81         86083
# 86588 2020-08-31 23:59:06              21           80         86083
# 86589 2020-08-31 23:59:36              21           80         86082
#
#        Counts_0.3um(#/0.1L)  Counts_0.5um(#/0.1L)  Counts_1.0um(#/0.1L)  \
# ...

# %%
x1 = df.groupby(df['Timestamp'].dt.date).mean()
x1.to_csv('E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\mean_daily.csv', index = False)
x1
# Out:
#             Temperature(C)  Humidity(%)  Pressure(Pa)  Counts_0.3um(#/0.1L)  \
# Timestamp
# 2020-01-27       21.702028    42.510920  86101.809672           3135.051482
# 2020-01-28       17.279708    65.157748  86140.797776           3275.089646
# 2020-01-29       18.260507    60.686349  86288.115318           1893.732893
# 2020-01-30       20.905837    48.641765  86254.018416           2273.385337
# 2020-01-31       21.988178    39.544159  86099.330320           3328.755563
# ...                    ...          ...           ...                   ...
# 2020-08-27       22.290928    77.572124  85912.156761            446.240181
# 2020-08-28       21.071950    82.846715  85767.865832            271.192909
# 2020-08-29       21.215080    83.287005  85732.894719            267.374913
# 2020-08-30       20.886300    84.300417  85769.526773            353.634214
# 2020-08-31       21.500174    81.541189  85921.593326            546.809176
#
# ...

# %%
x1 = df.groupby(df['new_date']).mean()
x1.to_csv('E:\KESHMINA\M-Tech\Semester-2\ES 670\drive-download-20220127T074114Z-001\mean_daily.csv', index = False)
x1['date'] = df['new_date'].unique()
x1
# Out:
#             Temperature(C)  Humidity(%)  Pressure(Pa)  Counts_0.3um(#/0.1L)  \
# new_date
# 2020-01-27       21.702028    42.510920  86101.809672           3135.051482
# 2020-01-28       17.279708    65.157748  86140.797776           3275.089646
# 2020-01-29       18.260507    60.686349  86288.115318           1893.732893
# 2020-01-30       20.905837    48.641765  86254.018416           2273.385337
# 2020-01-31       21.988178    39.544159  86099.330320           3328.755563
# ...                    ...          ...           ...                   ...
# 2020-08-27       22.290928    77.572124  85912.156761            446.240181
# 2020-08-28       21.071950    82.846715  85767.865832            271.192909
# 2020-08-29       21.215080    83.287005  85732.894719            267.374913
# 2020-08-30       20.886300    84.300417  85769.526773            353.634214
# 2020-08-31       21.500174    81.541189  85921.593326            546.809176
#
# ...

# %%
d1 = f1.groupby(f1['Timestamp'].dt.date).mean()
d2 = f2.groupby(f2['Timestamp'].dt.date).mean()
d3 = f3.groupby(f3['Timestamp'].dt.date).mean()
d4 = f4.groupby(f4['Timestamp'].dt.date).mean()
d5 = f5.groupby(f5['Timestamp'].dt.date).mean()
d6 = f6.groupby(f6['Timestamp'].dt.date).mean()
d7 = f7.groupby(f7['Timestamp'].dt.date).mean()
d8 = f8.groupby(f8['Timestamp'].dt.date).mean()

# %%
d1['date'] = f1['new_date'].unique()
d2['date'] = f2['new_date'].unique()
d3['date'] = f3['new_date'].unique()
d4['date'] = f4['new_date'].unique()
d5['date'] = f5['new_date'].unique()
d6['date'] = f6['new_date'].unique()
d7['date'] = f7['new_date'].unique()
d8['date'] = f8['new_date'].unique()
d6
# Out:
#             Temperature(C)  Humidity(%)  Pressure(Pa)  Counts_0.3um(#/0.1L)  \
# Timestamp
# 2020-06-01       22.276119    67.201493  86159.126866            663.917910
# 2020-06-06       25.010309    65.927835  85903.793814           1854.082474
# 2020-06-07       31.287535    46.917847  85837.335694            648.491501
# 2020-06-08       23.920000    67.360000  85898.780000            646.580000
# 2020-06-09       25.311302    66.958361  85866.825512            794.859220
# 2020-06-10       23.987399    70.066153  85789.833392            571.006650
# 2020-06-11       24.639208    68.323601  85613.590198            315.289885
# 2020-06-12       26.681043    63.141565  85407.943652            302.253565
# 2020-06-13       24.536186    68.867780  85405.654141            366.964509
# 2020-06-14       24.875261    70.183808  85546.904795            248.817234
# 2020-06-15       23.476372    75.807158  85524.878388            181.225156
# ...

# %% [markdown]
# # Box Plot for span of daily mean PM2.5 in different months

# %%
data = [d1['PM2.5_Atm(ug/m3)'], d2['PM2.5_Atm(ug/m3)'], d3['PM2.5_Atm(ug/m3)'], d4['PM2.5_Atm(ug/m3)'], d5['PM2.5_Atm(ug/m3)'], d6['PM2.5_Atm(ug/m3)'], d7['PM2.5_Atm(ug/m3)'],d8['PM2.5_Atm(ug/m3)']]
labels = ['Jan','Feb', 'March', 'April', 'May', 'June', 'July', 'Aug']

# plot the figure
plt.figure(figsize=(10, 8))
plt.boxplot(data, labels=labels)
plt.title("Box Plot for span of daily mean PM2.5 in different months", fontsize=16)
plt.xlabel("particulate matter size", fontsize=14)
plt.ylabel("concentration", fontsize=14)
#plt.savefig("box_mat6")
plt.show()

# %%
d6.describe()
# Out:
#        Temperature(C)  Humidity(%)  Pressure(Pa)  Counts_0.3um(#/0.1L)  \
# count       26.000000    26.000000     26.000000             26.000000
# mean        24.992547    67.720352  85698.953381            583.813624
# std          2.222050     7.113483    174.940568            350.047972
# min         22.276119    46.917847  85405.654141            163.857789
# 25%         23.419041    64.098554  85563.576146            307.182096
# 50%         24.587697    67.841800  85709.635240            557.418659
# 75%         26.550570    73.658614  85807.886398            772.252253
# max         31.287535    77.858582  86159.126866           1854.082474
#
#        Counts_0.5um(#/0.1L)  Counts_1.0um(#/0.1L)  Counts_2.5um(#/0.1L)  \
# count             26.000000             26.000000             26.000000
# mean             187.901617             31.582426              6.290818
# std              113.329281             21.950951              4.764626
# ...

# %% [markdown]
# # Monthy Variation in non-lockdown months

# %%
plt.figure(figsize=(10, 5))
plt.plot(x1['date'],x1['PM2.5_Atm(ug/m3)'], color = 'green')
plt.plot(x1['date'],x1['Humidity(%)'], color = 'pink')
plt.plot(x1['date'],x1['PM10_Atm(ug/m3)'], color = 'blue')
plt.plot(x1['date'],x1['PM1_Atm(ug/m3)'], color = 'yellow')
plt.title("Timeseries Plot for of PM2.5 daily mean from Jan-2020 to Aug-2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(d2['date'],d2['PM2.5_Atm(ug/m3)'], color = 'red')
plt.title("Timeseries Plot for of PM2.5 daily_mean in february", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.figure(figsize=(20, 5))
plt.plot(d3['date'],d3['PM2.5_Atm(ug/m3)'], color = 'red')
plt.title("Timeseries Plot for of PM2.5 daily_mean in march", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.figure(figsize=(20, 5))
plt.plot(d4['date'],d4['PM2.5_Atm(ug/m3)'], color = 'red')
plt.title("Timeseries Plot for of PM2.5 daily_mean in april", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.figure(figsize=(20, 5))
plt.plot(d5['date'],d5['PM2.5_Atm(ug/m3)'], color = 'red')
plt.title("Timeseries Plot for of PM2.5 daily_mean in may", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.figure(figsize=(20, 5))
plt.plot(d6['date'],d6['PM2.5_Atm(ug/m3)'], color = 'red')
plt.title("Timeseries Plot for of PM2.5 daily_mean in june", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.figure(figsize=(20, 5))
plt.plot(d7['date'],d7['PM2.5_Atm(ug/m3)'], color = 'red')
plt.title("Timeseries Plot for of PM2.5 daily_mean in july", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.figure(figsize=(20, 5))
plt.plot(d8['date'],d8['PM2.5_Atm(ug/m3)'], color = 'red')
plt.title("Timeseries Plot for of PM2.5 daily_mean in august", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
# Out:
# Text(0, 0.5, 'PM2.5 Conc')

# %% [markdown]
# # Dirunal variation

# %%
plt.figure(figsize=(10, 5))
plt.plot(f1['Timestamp'][:1285],f1['PM2.5_Atm(ug/m3)'][:1285], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 27th Jan 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
#plt.savefig("box_mat6")
plt.show()
plt.figure(figsize=(10, 5))
plt.plot(f1['Timestamp'][1285:4163],f1['PM2.5_Atm(ug/m3)'][1285:4163], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 28th Jan 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
plt.figure(figsize=(10, 5))
plt.plot(f2['Timestamp'][:2878],f2['PM2.5_Atm(ug/m3)'][:2878], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 1st feb 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
plt.figure(figsize=(10, 5))
plt.plot(f2['Timestamp'][2878:5756],f2['PM2.5_Atm(ug/m3)'][2878:5756], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 2nd feb 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
plt.figure(figsize=(10, 5))
plt.plot(f3['Timestamp'][2878:5756],f3['PM2.5_Atm(ug/m3)'][2878:5756], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 2nd march 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
# Out:
# Text(0, 0.5, 'PM2.5 Conc')

# %%
plt.figure(figsize=(10, 5))
plt.plot(f4['Timestamp'][2878:5756],f4['PM2.5_Atm(ug/m3)'][2878:5756], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 2nd April 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
plt.figure(figsize=(10, 5))
plt.plot(f5['Timestamp'][2878:5756],f5['PM2.5_Atm(ug/m3)'][2878:5756], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 2nd may 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
plt.figure(figsize=(10, 5))
plt.plot(f6['Timestamp'][2878:5756],f6['PM2.5_Atm(ug/m3)'][2878:5756], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 2nd june 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
plt.figure(figsize=(10, 5))
plt.plot(f7['Timestamp'][2878:5756],f7['PM2.5_Atm(ug/m3)'][2878:5756], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 2nd july 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
plt.figure(figsize=(10, 5))
plt.plot(f8['Timestamp'][2878:5756],f8['PM2.5_Atm(ug/m3)'][2878:5756], color = 'blue')
plt.title("Hourly Variationfor of PM2.5 on 2nd August 2020", fontsize=16)
plt.xlabel("Time", fontsize=14)
plt.ylabel("PM2.5 Conc", fontsize=14)
# Out:
# Text(0, 0.5, 'PM2.5 Conc')
